# %%
#1. O URL para o conjunto de dados é: https://catalog.data.gov/dataset?q=brand&sort=score+desc%2C+name+asc&as_sfid=AAAAAAX8tSkIYjz9UeZrMfKy2fdGuYORPazPpoL-_QvkLsgPhshKSLCDvirFBgpzf-WwjQJIvbZXUJ3Du_GGzdcyy_Te8VRdag6r-YdHp0cOXH5hLFRGlWhrzk75DGwSRRhFM9A%3D&as_fid=e017b5a30c6429cd758166c0152bfed6e0bd7723

# %%
#2. Escolhemos este conjunto de dados, pois é fácil de ler, mas tem informação suficiente para trabalhar, também por ser um tema interessante, as marcas de licores dos EUA

# %%
import pandas as pd
df1 = pd.read_csv("D:/Work/CDM/Programação e algoritmos/PAII/python/Liquor_Brands_2.csv")

# %%
df1 = pd.read_csv("D:/Work/CDM/Programação e algoritmos/PAII/python/Liquor_Brands_2.csv", nrows=10)

# %%
df1
# Out:
#                                           BRAND-NAME CT-REGISTRATION-NUMBER  \
# 0                           DOUBLE COCONUT MIND HAZE            LBD.0162292
# 1                                  MARQUES DEL ATRIO            LBD.0164039
# 2                                  CAPRICCIO SANGRIA            LBD.0163167
# 3                      BRUNO GIACOSA RED BAROLO DOCG            LBD.0165342
# 4                          2013 RESERVE DRY RIESLING            LBD.0158268
# 5                       OVUM RIESLING 'OFF THE GRID'            LBD.0160724
# 6              GLEN FOHDRY MIZUNARA OAK CASK 12 YEAR            LBD.0166031
# 7  LOMA VISTA VINEYARDS CABERNET SAUVIGNON NAPA V...            LBD.0164133
# 8  PATRICIA GREEN PINOT NOIR 'PATTY GREEN COMMENM...            LBD.0161876
# 9                  JOSEPH MAGNUS CIGAR BLEND BOURBON            LBD.0165360
#
#    STATUS               EFFECTIVE              EXPIRATION  \
# 0  ACTIVE        12/10/2019 00:00        12/09/2022 00:00
# ...

# %%
#5. Os tipos de dados usados nestes atributos são, númericos inteiros, strings e listas.
